# %%
#1.wap to check the given number is even or odd (take user input)


a = eval(input('enter the number'))

if a % 2 == 0 :
    print(complex(a))

else:
    print('number is odd',a)

# %%
#2.wap to check whether the male and female are eligible for wedding (take user input)

m = eval(input('enter the age for male'))
f = eval(input('enter the age for female'))

if m >= 21 and f >= 18:
    print('eligible for wedding')

else:
    print('not eligible')
# Out:
# enter the age for male 22
# enter the age for female 18
# eligible for wedding

# %%
#3.wap to find greater value among the two number

n1=34
n2=54

if n1 > n2 :
    print('n1 is greater than n2')

else:
    print('n2 is greater than n1')
# Out:
# n2 is greater than n1

# %%
#4.wap to check if the given number is even or not,if it is not even add+1 and make it even (take user input)

a = eval(input('enter the number'))

if a % 2 != 0 :
    print(a+1)

else:
    print(a)
# Out:
# enter the number 5
# 6

# %%
#5.wap to check whether the first character in the given string is starting with uppercase or Not if it is not Then capitalize it

s="python"
if s[0].isupper():
    print('string is capitalize')

else:
    print(s.capitalize())
# Out:
# Python

# %%
#6.wap to check if the given number is even ,if it is even reduce it to its Half else make exponent (take user input)

a = eval(input('Enter the number'))

if a % 2 == 0:
    print(a/2)

else:
    print(a**2)
# Out:
# Enter the number 5
# 25

# %%
#7.wap to check number should be divisible by 3 and 7 (take user input)

a = eval(input('Enter the number'))

if a % 3 == 0 and a % 7 == 0:
    print('number is divisible by 3 and 7')

else :
    print('number is not divisible')
# Out:
# Enter the number 21
# number is divisible by 3 and 7

# %%
#.wap if the length of string is even then reverse else convert into upper case (take user input)

a = eval(input('Enter the string'))

if len(a) % 2 == 0:
    print(a[::-1])
else:
    print(a.upper())
# Out:
# Enter the string 'vaibha'
# ahbiav

# %%
#9.wap to check a number is +ve/-ve number (take user input)
a = eval(input('Enter the number'))

if a > 0:
    print('number is positive')

else:
    print('number is negative')
# Out:
# Enter the number -55
# number is negative

# %%
#10.wap to check a data is individual or collection data type or not (take user input)

a = eval(input('enter the datatype'))

if type(a) in (str,list,set,tuple,dict):
    print('its collection data type')

else:
    print('it is single value data type')
# Out:
# enter the datatype 'str'
# its collection data type

# %%
#10.wap to check a data is individual or collection data type or not (take user input)

a = eval(input('enter the datatype'))

if isinstance(a,(str,list,set,tuple,dict)):
    print('its collection data type')

else:
    print('it is single value data type')
# Out:
# enter the datatype 'str'
# its collection data type

# %%
#13.wap to check whether the specified character is present in the given string

a = eval(input('enter the number'))

s="Python"

if a in s:
    print('character is present in string')

else:
    print('character is not present in string')
# Out:
# enter the number 'k'
# character is not present in string

# %%
#14.wap to check the length of dictionary and length of dictionary is even or Not if even print as it is or else add a item and make it even

D={"a":"apple","b":"ball","c":"cat"}

if len(D) % 2 == 0:
    print(D)

else:
    D.update({"d": "dog"})
    print(D)
# Out:
# {'a': 'apple', 'b': 'ball', 'c': 'cat', 'd': 'dog'}

# %%
#15.wap to check the given number is greater than 5,if it is greater convert that number into negative number else print the same number

a = eval(input('Enter the number'))

if a > 5:
    print(-abs(a))

else:
    print(a)
# Out:
# enter the number 2
# 2

# %%
#16.wap to check the given number is smaller than 10 ,if it is smaller find the exponent of it else print the number as it is


a = eval(input('Enter the number'))

if a < 10:
    print(a**2)

else:
    print(a)
# Out:
# Enter the number 22
# 22

# %%
#17.wap to check the given number is odd, if it is odd divide it by 2 and print reminder and quotient else print it is even (take user input)

a = eval(input('Enter the number'))

if a % 2 == 1:
    print(divmod(a,2))

else:
    print('It is even')
# Out:
# Enter the number 5
# (2, 1)

# %%
#18.wap to check if the given character is alphabets or Not ,if it is alphabet create a replica of it for 2 times. (take user input)

a = eval(input('ENter the character'))

if a.isalpha():
    print(a+a)

else:
    print('character is not alphabet')
# Out:
# ENter the character '5'
# character is not alphabet
