# %%
#1.wap to perform addition and subtraction if "a" is greater than "b" return sum else return difference
a = int(input('Enter the first number'))
b = int(input('Enter the second number'))
def addsub():
    if a > b:
        print(f'sum of {a} + {b} is {a+b}')

    else:
        print(f'substraction of {a} - {b} is {a-b}')

addsub()
# Out:
# Enter the first number 10
# Enter the second number 5
# sum of 10 + 5 is 15

# %%
#2.wap to check string is palindrome or not (take user input)

a = eval(input('Enter the string'))

def palindrome():

    if a == a[::-1]:
        print('string is palindrome')
    else:
        print('string is not palindrome')

palindrome()
# Out:
# Enter the string '121'
# string is palindrome

# %%
#3.wap to return length of variable keywords arguments


def Length(**kwargs):
    return len(kwargs)

x=Length(a=90,b="c",c=123,d=100)
print(x)

print()

#without using return keyword
def Length1(**kwargs):
    print(len(kwargs))
Length1(w=11,r=45,m=999)

print()

#without using inbuilt function
def Length3(**kwargs):
    count=0
    for i in kwargs:
        count+=1
    print(count)
Length3(x=99,y=88,z="abc",d="xyz",v="sql",h="python")
# Out:
# 4
#
# 3
#
# 6

# %%
#4.wap to return length of the variable positional arguments

def Length(*args):
    return len(args)

x=Length(10,20,30,40,50)
print(x)

print()
# Out:
# 5

# %%
#5.waf to search for character in a given string and return corresponding index
string="coding part is done"



def charpos():
    a = input('enter the character to find')
    if a in string:
        print(string.index(a))
    

charpos()
# Out:
# enter the character to find i
# 3

# %%
#6.wap to squaring of the element in the given list
l=[1,2,3,4,5]

def square():
    for i in l:
        print(i*i)

square()
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
#7.wap to fetch last digit number

def lastnumber(x):
    return x%10
print(lastnumber(123))
# Out:
# 3

# %%
#8.wap to read 3 numbers from the user,first two numbers should be added and the result of addition should be subtracted by third number


def operation():
    a = int(input('enter first number'))
    b = int(input('enter second number'))
    c = int(input('enter third number'))

    d = (a+b)-c
    print(d)

operation()
# Out:
# enter first number 5
# enter second number 5
# enter third number 1
# 9

# %%
#9.wap to find square,cube,square root and cube root of a number

# %%
#10.wap to check the given characters is alphabets or digit or special characters

def checkchar():
    a = input('enter the number')
    if a.isalpha():
        print('given character is alphabet')
    elif a.isdigit():
        print('given character is digit')
    else:
        print('given character is special character')
        
checkchar()
# Out:
# enter the number 5
# given character is digit

# %%
#11.wap to check given iterable is a sequence,if it is a sequence reverse it,if not add one extra element to the iterable

def process_iterable(iterable):
    if isinstance(iterable, (list, tuple, str)):
        print("Given iterable is a sequence.")
        reversed_iterable = iterable[::-1]
        print("Reversed sequence:", reversed_iterable)
    else:
        print("Given iterable is NOT a sequence.")
        new_iterable = list(iterable)
        new_iterable.append("new_element")
        print("Updated iterable with one extra element:", new_iterable)

# Examples
process_iterable([1, 2, 3])           # List - sequence
process_iterable((4, 5, 6))           # Tuple - sequence
process_iterable("Python")           # String - sequence
process_iterable({1, 2, 3})          # Set - not a sequence
process_iterable({1: 'a', 2: 'b'})   # Dict - not a sequence


#chatgpt

# %%
#12.write a function to print the below output
#func("TRACXN",1)
#should print RCN

def func(s,n):
    print(s[n::2])

# Test
func("TRACXN", 1)
# Out:
# RCN

# %%
# 13.write a function to print the below output
# func("TRACXN",0)
#should print TAX

def func(s,n):
    print(s[n::2])

func("TRACXN",0)
# Out:
# TAX

# %%
# 14.A function take variable number of positional arguments
#    as input. how to check if the arguments are more than 5.

def argu(*args):
    if len(args) > 5:
        print('more than 5 arguments')

    else:
        print('not more tahn 5 argument')

argu(10,20,30)
argu(10,20,30,40,50,60)
# Out:
# not more tahn 5 argument
# more than 5 arguments

# %%
#15.waf to return a dictionary with characters and ascii value pair

def dicti():
    dic = {}
    i = 97
    while i < 122 :
        dic[chr(i)] = i
        i+=1

    print(dic)
dicti()
# Out:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107, 'l': 108, 'm': 109, 'n': 110, 'o': 111, 'p': 112, 'q': 113, 'r': 114, 's': 115, 't': 116, 'u': 117, 'v': 118, 'w': 119, 'x': 120, 'y': 121}

# %%
#16.waf to reverse a iterable if you are passing string or list or tuple else print type of the data

def itera(a):
    if isinstance(a,(list,str,tuple)):
        print(a[::-1])
    else:
        print(type(a))
itera({10,20,30})
# Out:
# <class 'set'>

# %%
#17.wap to check if a given character is alphabet or digit or special character.

def checkchar(a):
    if a.isalpha():
        print('given character is alphabet')
    elif a.isdigit():
        print('given character is digit')
    else:
        print('given character is special character')
checkchar('c')
checkchar('7')
checkchar('&')
# Out:
# given character is alphabet
# given character is digit
# given character is special character

# %%
#18.write a function to check the given number is prime or not

def is_prime(n):
    # Check if n is less than 2
    if n <= 1:
        return False
    
    # Check divisibility from 2 to square root of n
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False  # n is divisible by i, so it is not prime
    
    return True  # n is prime if no divisors were found

# Example usage:
num = 29
if is_prime(num):
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")

#chatgpt
# Out:
# 29 is a prime number.

# %%
#19.wap to return length of an iterable without using len() function

def leng(a):
    count = 0
    for i in a:
        count+=1
    print(count)

leng([10,20,30,40,50])
leng('helloh')
# Out:
# 5
# 6

# %%
#20.wap to count the number of arguments passed inside the function call(both positional and keyword)

def countargu(*args,**kwargs):
    a = len(args)
    b = len(kwargs)

    print(f'length of args is {a}')
    print(f'length of kwargs is {b}')

countargu(10,20,30,40,50,a=10,b=20,c=30,d=40)
# Out:
# length of args is 5
# length of kwargs is 4

# %%
def sum_of_digits(n):
    return sum(int(digit) for digit in str(abs(n)))

# Call the function and print the result
print(sum_of_digits(12345))  # Output: 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2     return sum(int(digit) for digit in str(abs(n)))
#       4 # Call the function and print the result
# ----> 5 print(sum_of_digits(12345))  # Output: 15
#
# Cell In[20], line 2, in sum_of_digits(n)
#       1 def sum_of_digits(n):
# ----> 2     return sum(int(digit) for digit in str(abs(n)))
#
# Cell In[7], line 6, in sum(a)
#       5 def sum(a):
# ----> 6     return sum(int(a))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'generator'

# %%
# 22.Write a function to find the largest of three numbers.
# Input: 3, 7, 2
# Output: 7

def largest(a,b,c):
    if  a > b and a > c:
        print(f'{a} is  greater than {b} and {c}')
    elif b > a and b > c:
        print(f'{b} is greater than {a} and {c}')
    else:
        print(f'{c} is greater than {a} and {c}')

largest(3,7,2)
# Out:
# 7 is greater than 3 and 2

# %%
# 23.Create a function that counts the number of vowels in a string.
# Input: "hello"
# Output: 2

def countvow(a):
    count = 0
    vowels = 'aeiouAEIOU'  # To count both lowercase and uppercase vowels
    for char in a:
        if char in vowels:
            count += 1
    return count

# Example usage:
print(countvow('hello'))  # Output: 2

#chatgpt
# Out:
# 2

# %%
# 24. Write a function to calculate the factorial of a given number.
# Input: 5
# Output: 120

def facto(a):
    i = 1
    while a > 1:
        i = i * a
        a -= 1
    return i

print(facto(5))  # Output: 120
# Out:
# 120

# %%
# 25.Write a function that counts the number of words in a given sentence.
# Input: "This is a sample sentence."
# Output: 5

def count_words(a):
    b = a.split()
    print(len(b))

count_words("This is a sample sentence.")
# Out:
# 5

# %%
# 26. Write a function that removes duplicates from a given list.
# Input: [1, 2, 2, 3, 4, 4, 5]
# Output: [1, 2, 3, 4, 5]

def removeduplicate(a):
    b = set(a)
    c = list(b)
    c.sort()
    print(c)
    
removeduplicate([1, 2, 2, 3, 4, 4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# 27. Write a function that returns the middle element of a list.
# Input: [1, 2, 3, 4, 5]
# Output: 3

def midelement(a):
    b = len(a)//2
    print(a[b])
midelement([1, 2, 3, 4, 5])
midelement([10,20,30,40,50,60,70])
# Out:
# 3
# 40

# %%
# 28.waf to print index and element pair
# l = ["amazon", "flipkart", "ebay", "insta", "twitter", "meta"]

def indexele(a):
    for i in enumerate(a):
        print(i)

indexele(["amazon", "flipkart", "ebay", "insta", "twitter", "meta"])
# Out:
# (0, 'amazon')
# (1, 'flipkart')
# (2, 'ebay')
# (3, 'insta')
# (4, 'twitter')
# (5, 'meta')

# %%
# 29.waf to create a dictionary Ascii and character pair
# l=[89,51,111,77,108,120]

def asciichar(a):
    dict = {}
    for i in a:
        dict[i] = chr(i)
    print(dict)

asciichar([89,51,111,77,108,120])
# Out:
# {89: 'Y', 51: '3', 111: 'o', 77: 'M', 108: 'l', 120: 'x'}

# %%
# #30.waf to create a dictionary word and reverse word pair
# s="tomorrow is weekend and non-veg special"
# o/p:-->{'tomorrow': 'worromot', 'is': 'si', 'weekend': 'dnekeew', 'and': 'dna', 'non-veg': 'gev-non', 'special': 'laiceps'}

def dictpair(a):
    dict = {}
    b = a.split()
    for i in b:
        dict[i] = i[::-1]
    print(dict)

dictpair("tomorrow is weekend and non-veg special")
# Out:
# {'tomorrow': 'worromot', 'is': 'si', 'weekend': 'dnekeew', 'and': 'dna', 'non-veg': 'gev-non', 'special': 'laiceps'}
